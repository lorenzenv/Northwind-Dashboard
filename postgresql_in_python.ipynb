# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
uri = 'postgresql://vali:shibuya123@127.0.0.1:5432/northwind'

# %%
uri
# Out:
# 'postgresql://vali:shibuya123@127.0.0.1:5432/northwind'

# %%
engine = create_engine(uri, echo=False)

# %%
engine
# Out:
# Engine(postgresql://vali:***@127.0.0.1:5432/northwind)

# %%
query = "SELECT * FROM products;"

df = pd.read_sql(query, engine, index_col="productid")
df
# Out:
#                                productname  supplierid  categoryid  \
# productid
# 1                                     Chai           1           1
# 2                                    Chang           1           1
# 3                            Aniseed Syrup           1           2
# 4             Chef Anton's Cajun Seasoning           2           2
# 5                   Chef Anton's Gumbo Mix           2           2
# ...                                    ...         ...         ...
# 73                              Röd Kaviar          17           8
# 74                           Longlife Tofu           4           7
# 75                    Rhönbräu Klosterbier          12           1
# 76                            Lakkalikööri          23           1
# 77         Original Frankfurter grüne Soße          12           2
#
#                quantityperunit  unitprice  unitsinstock  unitsonorder  \
# productid
# ...
